# %% [markdown]
# ### BIA660
# ### Xianning Zhang
# #### Assignment 1

# %%
import requests

# %% [markdown]
# ###  A

# %%
searchA = requests.get('https://www.google.com/search?source=hp&ei=QJ9ZXKmEOM6xggf1rqOgAw&q=Tim+Berners-Lee&btnK=Google+Search&oq=Tim+Berners-Lee&gs_l=psy-ab.3..0l10.1680.21620..22621...0.0..0.391.1522.11j3j0j1......0....1..gws-wiz.....0..0i131j0i131i10.J0AGurkCXSw')

# %%
print(searchA.content)
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><noscript><meta content="0;url=/search?q=Tim+Berners-Lee&amp;ie=UTF-8&amp;gbv=1&amp;sei=oaZZXJirI-eJggfdjouoDw" http-equiv="refresh"><style>table,div,span,p{display:none}</style><div style="display:block">Please click <a href="/search?q=Tim+Berners-Lee&amp;ie=UTF-8&amp;gbv=1&amp;sei=oaZZXJirI-eJggfdjouoDw">here</a> if you are not redirected within a few seconds.</div></noscript><title>Tim Berners-Lee - Google Search</title><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{
# ...

# %%
print(searchA.status_code)
# Out:
# 200

# %%
searchA.headers
# Out:
# {'Date': 'Tue, 05 Feb 2019 15:07:13 GMT', 'Expires': '-1', 'Cache-Control': 'private, max-age=0', 'Content-Type': 'text/html; charset=ISO-8859-1', 'P3P': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."', 'Content-Encoding': 'gzip', 'Server': 'gws', 'X-XSS-Protection': '1; mode=block', 'X-Frame-Options': 'SAMEORIGIN', 'Set-Cookie': '1P_JAR=2019-02-05-15; expires=Thu, 07-Mar-2019 15:07:13 GMT; path=/; domain=.google.com, CGIC=IgMqLyo; expires=Wed, 07-Aug-2019 06:01:49 GMT; path=/complete/search; domain=.google.com; HttpOnly, CGIC=IgMqLyo; expires=Wed, 07-Aug-2019 06:01:49 GMT; path=/search; domain=.google.com; HttpOnly, NID=158=iskqXUKemmJfDK_owd9T-9-4jX8FjB77rMoIfubqh-cl1mk5l1E0wCP8Kn9mNsP7uYpL8_ZCYmUNdkY4NhnuX82kLKiAmNDjlzAB7paGTnM1OGbiEIZpsRos-BsZFa7lItQP8I5d5kVIN9t6EbawsKvl8Vqq1XIXr96ZqP9wxK0; expires=Wed, 07-Aug-2019 15:07:13 GMT; path=/; domain=.google.com; HttpOnly', 'Alt-Svc': 'quic=":443"; ma=2592000; v="44,43,39"', 'Transfer-Encoding': 'chunked'}

# %% [markdown]
# ### B

# %%
searchB = requests.post('https://www.google.com/search?ei=OaZZXKbLC4Hx_Abh_pH4DQ&q=98hjsfeiufh&oq=98hjsfeiufh&gs_l=psy-ab.3...265648.265648..266456...0.0..0.108.108.0j1......0....1..gws-wiz.eGI71rgS0Zs')

# %%
print(searchB.content)
# Out:
# b'<!DOCTYPE html>\n<html lang=en>\n  <meta charset=utf-8>\n  <meta name=viewport content="initial-scale=1, minimum-scale=1, width=device-width">\n  <title>Error 405 (Method Not Allowed)!!1</title>\n  <style>\n    *{margin:0;padding:0}html,code{font:15px/22px arial,sans-serif}html{background:#fff;color:#222;padding:15px}body{margin:7% auto 0;max-width:390px;min-height:180px;padding:30px 0 15px}* > body{background:url(//www.google.com/images/errors/robot.png) 100% 5px no-repeat;padding-right:205px}p{margin:11px 0 22px;overflow:hidden}ins{color:#777;text-decoration:none}a img{border:0}@media screen and (max-width:772px){body{background:none;margin-top:0;max-width:none;padding-right:0}}#logo{background:url(//www.google.com/images/branding/googlelogo/1x/googlelogo_color_150x54dp.png) no-repeat;margin-left:-5px}@media only screen and (min-resolution:192dpi){#logo{background:url(//www.google.com/images/branding/googlelogo/2x/googlelogo_color_150x54dp.png) no-repeat 0% 0%/100% 100%;-moz-bord
# ...

# %%
print(searchB.status_code)
# Out:
# 405

# %%
searchB.headers
# Out:
# {'Allow': 'GET, HEAD', 'Date': 'Tue, 05 Feb 2019 15:21:14 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Server': 'gws', 'Content-Length': '1754', 'X-XSS-Protection': '1; mode=block', 'X-Frame-Options': 'SAMEORIGIN', 'Alt-Svc': 'quic=":443"; ma=2592000; v="44,43,39"'}

# %% [markdown]
# ### C

# %%
searchC = requests.get('https://www.fbi.gov/crime-in-the-u.s/2017/crime-in-the-u.s.-2018')

# %%
print(searchC.status_code)
# Out:
# 404

# %%
searchC.headers
# Out:
# {'Date': 'Tue, 05 Feb 2019 15:31:18 GMT', 'Content-Type': 'text/html;charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d653de01323f69041ffbbb6ec87c7cc1e1549380678; expires=Wed, 05-Feb-20 15:31:18 GMT; path=/; domain=.fbi.gov; HttpOnly; Secure', 'Content-Language': 'en-us', 'Expires': 'Tue, 05 Feb 2019 15:51:18 GMT', 'X-Frame-Options': 'SAMEORIGIN', 'X-Theme-Disabled': '', 'X-Ua-Compatible': 'IE=edge', 'CF-Cache-Status': 'HIT', 'Cache-Control': 'public, max-age=1200', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'X-Content-Type-Options': 'nosniff', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Vary': 'Accept-Encoding', 'Server': 'cloudflare', 'CF-RAY': '4a466c578c2c9242-EWR', 'Content-Encoding': 'gzip'}
